# %%
import altair as alt
import pandas as pd

# %%
data = pd.read_csv("breast-cancer.csv")
data.head(10)
# Out:
#                   class    age menopause tumor-size inv-nodes node-caps  \
# 0  no-recurrence-events  30-39   premeno      30-34       0-2        no
# 1  no-recurrence-events  40-49   premeno      20-24       0-2        no
# 2  no-recurrence-events  40-49   premeno      20-24       0-2        no
# 3  no-recurrence-events  60-69      ge40      15-19       0-2        no
# 4  no-recurrence-events  40-49   premeno        0-4       0-2        no
# 5  no-recurrence-events  60-69      ge40      15-19       0-2        no
# 6  no-recurrence-events  50-59   premeno      25-29       0-2        no
# 7  no-recurrence-events  60-69      ge40      20-24       0-2        no
# 8  no-recurrence-events  40-49   premeno      50-54       0-2        no
# 9  no-recurrence-events  40-49   premeno      20-24       0-2        no
#
#    deg-malig breast breast-quad irradiat
# 0          3   left    left_low       no
# 1          2  right    right_up       no
# 2          2   left    left_low       no
# ...

# %%
brush = alt.selection_interval()

# %%
points = alt.Chart(data).mark_point().encode(
    x='age:N',
    y='tumor-size:N',
    color=alt.condition(brush, 'breast:O', alt.value('blue'))
).add_selection(
    brush
)

points
# Out:
# alt.Chart(...)

# %%
points = alt.Chart(data).mark_point().encode(
    x='age:N',
    y='class:O',
    color=alt.condition(brush, 'breast:O', alt.value('green'))
).add_selection(
    brush
)

points
# Out:
# alt.Chart(...)

# %%
bars = alt.Chart(data).mark_bar().encode(
    y='breast:O',
    color='breast:N',
    x='count(breast):O'
)

bars
# Out:
# alt.Chart(...)

# %%
bars = alt.Chart(data).mark_bar().encode(
    y='breast:O',
    color='breast:N',
    x='count(breast):O'
).transform_filter(
    brush
)

# %%
points & bars
# Out:
# alt.VConcatChart(...)

# %% [markdown]
# ### Explanation
# I have chosen the breast-cancer data from UCI.
# I have selected scatter plot and bar chart designs to visualise the dataset by using mark_point and mark_bar.
# My choice of design is guided by the nature of the data in the dataset. As most of the features are categorical data, so I may be more interested in quantifying some features. After obtaining a visualisation, it will be much easy to adjust certain quantities and see how it affects others.
